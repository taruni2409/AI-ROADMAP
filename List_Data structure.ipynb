# %%
L=[]
L
# Out:
# []

# %%
type(L)
# Out:
# list

# %%
print(len(L))
# Out:
# 0

# %%
L.append(10)

# %%
L
# Out:
# [10]

# %%
L.append(20)
L.append(30)
L.append(40)
L.append(40)
L.append(50)

# %%
L
# Out:
# [10, 20, 30, 40, 20, 30, 40, 40, 50]

# %%
print(len(L))
# Out:
# 9

# %%
L.append(60)
L.append(70)
L.append(80)
L.append(90)
L.append(101)

# %%
l1=[]
l1.append("Siri")
l1.append(25)
l1.append(True)
l1.append([1,5,6])

# %%
print(L)
print(l1)
# Out:
# [10, 20, 30, 40, 20, 30, 40, 40, 50, 60, 70, 80, 90, 101]
# ['Siri', 25, True, [1, 5, 6]]

# %%
for i in l1:
    print(i)
# Out:
# Siri
# 25
# True
# [1, 5, 6]

# %%
for i in enumerate(l1):
    print(i)
# Out:
# (0, 'Siri')
# (1, 25)
# (2, True)
# (3, [1, 5, 6])

# %%
L
# Out:
# [10, 20, 30, 40, 20, 30, 40, 40, 50, 60, 70, 80, 90, 101]

# %%
L[:]
# Out:
# [10, 20, 30, 40, 20, 30, 40, 40, 50, 60, 70, 80, 90, 101]

# %%
L[0]
# Out:
# 10

# %%
L[-1]
# Out:
# 101

# %%
L[-2]
# Out:
# 90

# %%
L[15]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 L[15]
#
# IndexError: list index out of range

# %%
L[1:3]
# Out:
# [20, 30]
