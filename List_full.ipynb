# %%
l=[]

# %%
type(l)
# Out:
# list

# %%
l.append(20)

# %%
l
# Out:
# [20]

# %%
l.append(20)
l.append(10)
l.append(30)

# %%
len(l)
# Out:
# 4

# %%
l2 = l.copy()

# %%
l2
# Out:
# [20, 20, 10, 30]

# %%
l3=[]
l3.append("Harry")
l3.append(2.5)
l3.append(True)
l3.append(3+2j)
l3.append(25)
print(l3)
# Out:
# ['Harry', 2.5, True, (3+2j), 25]

# %%
l2.count(20)
# Out:
# 2

# %%
print(id(l2))
print(id(l))
print(id(l3))
# Out:
# 4464354816
# 4464405952
# 4464403520

# %%
l3.count(25)
# Out:
# 1

# %%
l3
# Out:
# ['Harry', 2.5, True, (3+2j), 25]

# %%
l3[1]=230
print(l3)
# Out:
# ['Harry', 230, True, (3+2j), 25]

# %%
l2
# Out:
# [20, 20, 10, 30]

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l3
# Out:
# ['Harry', 230, True, (3+2j), 25]

# %%
l3.pop()
# Out:
# 25

# %%
l3
# Out:
# ['Harry', 230, True, (3+2j)]
